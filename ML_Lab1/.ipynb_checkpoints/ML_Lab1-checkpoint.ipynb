# %% [markdown]
# ### 导入必须的数学包和图形库并配置

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
import random
import pylab

# %% [markdown]
# ### 获得未加噪声的数据（x, y），正弦函数，周期为2$\pi$，取样步长为0.1$\pi$，取一个周期

# %%
T = 2 * math.pi
n = 2
step = (T / n) * 0.1

x_row = np.arange(0, 2*T, step, float)
    
y_row = np.sin(math.pi / 2 * x_row)

plt.scatter(x_row, y_row)
plt.show()
# Out:
# [ 0.          0.31415927  0.62831853  0.9424778   1.25663706  1.57079633
#   1.88495559  2.19911486  2.51327412  2.82743339  3.14159265  3.45575192
#   3.76991118  4.08407045  4.39822972  4.71238898  5.02654825  5.34070751
#   5.65486678  5.96902604  6.28318531  6.59734457  6.91150384  7.2256631
#   7.53982237  7.85398163  8.1681409   8.48230016  8.79645943  9.1106187
#   9.42477796  9.73893723 10.05309649 10.36725576 10.68141502 10.99557429
#  11.30973355 11.62389282 11.93805208 12.25221135]
# [ 0.          0.47369374  0.83435434  0.9959207   0.91983974  0.62426595
#   0.17972937 -0.30769437 -0.72169585 -0.96348575 -0.97536797 -0.75450718
#  -0.35360535  0.13167406  0.5855333   0.89967217  0.9991306   0.86017577
#   0.51596517  0.04863459 -0.43030122 -0.80655823 -0.99035374 -0.93783031
#  -0.66152114 -0.22735931  0.26105516  0.68717646  0.94932321  0.98494177
#   0.78553281  0.39867944 -0.08330711 -0.54541486 -0.87737531 -0.99997584
#  -0.8839614  -0.55701545 -0.09715407  0.38589029]

# %% [markdown]
# ### 为数据加上高斯白噪声，均值0，方差0.2

# %%
mu = 0
sigma = 0.2

x = x_row + random.gauss(mu, sigma)
y = y_row + random.gauss(mu, sigma)

plt.scatter(x, y)
plt.show()
# Out:
# [-0.2151633   0.09899597  0.41315524  0.7273145   1.04147377  1.35563303
#   1.6697923   1.98395156  2.29811083  2.61227009  2.92642936  3.24058862
#   3.55474789  3.86890715  4.18306642  4.49722569  4.81138495  5.12554422
#   5.43970348  5.75386275  6.06802201  6.38218128  6.69634054  7.01049981
#   7.32465907  7.63881834  7.9529776   8.26713687  8.58129613  8.8954554
#   9.20961467  9.52377393  9.8379332  10.15209246 10.46625173 10.78041099
#  11.09457026 11.40872952 11.72288879 12.03704805]
# [-2.60412429e-01  2.13281316e-01  5.73941915e-01  7.35508274e-01
#   6.59427313e-01  3.63853524e-01 -8.06830600e-02 -5.68106796e-01
#  -9.82108279e-01 -1.22389817e+00 -1.23578040e+00 -1.01491961e+00
#  -6.14017774e-01 -1.28738370e-01  3.25120874e-01  6.39259737e-01
#   7.38718174e-01  5.99763341e-01  2.55552741e-01 -2.11777842e-01
#  -6.90713646e-01 -1.06697066e+00 -1.25076616e+00 -1.19824274e+00
#  -9.21933566e-01 -4.87771738e-01  6.42733366e-04  4.26764033e-01
#   6.88910786e-01  7.24529344e-01  5.25120381e-01  1.38267008e-01
#  -3.43719541e-01 -8.05827287e-01 -1.13778774e+00 -1.26038826e+00
#  -1.14437383e+00 -8.17427877e-01 -3.57566497e-01  1.25477857e-01]

# %% [markdown]
# ### 根据最小二乘法使用1-16阶的多项式拟合数据

# %%
def least_square(x, y, order):
    matrix_left = np.empty([order + 1, order + 1], dtype = float)
    matrix_right = np.empty([order + 1, 1], dtype = float)
    for i in range(0, order + 1):
        row = matrix_left[i]
        for j in range(i, order + 1 + i):
            sum = 0
            for xx in x:
                sum = sum + xx**j
            row[j - i] = sum
    
    for i in range(0, order + 1):
        sum = 0
        j = 0
        for xx in x:
            sum = sum + y[j] * xx**i
            j = j + 1
        matrix_right[i][0] = sum
    
    return np.linalg.solve(matrix_left, matrix_right)

def func_solve(x, a):
    y=0
    for i in range(len(a)):
        y+=a[i]*x**i
    return y

pylab.rcParams['figure.figsize'] = (15.0, 8.0)
for i in range(16):
    ax = plt.subplot(4, 4, 1+i)
    ax.set_title('order=' + str(i+1))
    plt.xticks(())
    plt.yticks(())
    a = least_square(x, y, i)
    after_x = np.arange(-0.5, 2*T, 0.01)
    after_y = func_solve(after_x, a)
    plt.ylim([-1.3, 1.25])
    plt.plot(x, y, color='m', linestyle='', marker='.')
    plt.plot(after_x,after_y,color='g',linestyle='-',marker='')

plt.tight_layout()
plt.show()
